# %% [markdown]
# # The goal is to practise Tree-Based Methods and create a model to predict whether or not a customer will Churn (cancel their contract).

# %% [markdown]
# ### Importing the libraries needed.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading in the data.

# %%
df = pd.read_csv('../DATA/Telco-Customer-Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %% [markdown]
# ### Before converting the categorical columns to dummy variables I would like to see some statistical information about the numerical columns.

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# ## Now let's start with the exploratory data analysis.

# %% [markdown]
# ### Confirming that there are no NaN values.

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ### Finding the balance between Churn values.

# %%
sns.countplot(data=df, x='Churn');

# %% [markdown]
# ### I would like to know the distribution of total charges between Churn values.

# %%
sns.violinplot(data=df, x='Churn', y='TotalCharges')
plt.title('Distribution of Total Charges by Churn');

# %%
sns.histplot(data=df, x="TotalCharges", hue="Churn", element="step", stat="density", common_norm=False)
plt.title('Distribution of Total Charges by Churn');

# %% [markdown]
# ### Let's see a boxplot that shows the distribution of total charges, seperated by comtract type and churn class. We will do the same for monthly charges.

# %%
plt.figure(figsize=(14,8))
sns.boxplot(data=df, x='Contract', y='TotalCharges', hue='Churn');

# %%
plt.figure(figsize=(14,8))
sns.boxplot(data=df, x='Contract', y='MonthlyCharges', hue='Churn');

# %% [markdown]
# ### I would like to see the correlation between certain columns to the churn column, to do that I will create a new dataframe with the selected columns and any categorical colunns I will convert to dummy variables.

# %%
corr_df = pd.get_dummies(df[['gender', 'SeniorCitizen', 'Partner', 'Dependents','PhoneService', 'MultipleLines', 
 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'InternetService',
   'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']]).corr()

# %%
churn_corr_df = corr_df['Churn_Yes'].sort_values().drop(['Churn_No', 'Churn_Yes'])

# %%
plt.figure(figsize=(12,10))
sns.barplot(data=pd.DataFrame(churn_corr_df), y=pd.DataFrame(churn_corr_df).index, x='Churn_Yes');

# %% [markdown]
# ## Now we will do some Churn analysis.

# %% [markdown]
# ### Let's have a look at the different contract types.

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %% [markdown]
# ### Creating a histogram showing the tenure amount, which is the amount of months a customer has been or was a customer.

# %%
plt.figure(figsize=(14,6))
sns.histplot(data=df, x='tenure', bins=60);

# %% [markdown]
# ### Let's explore this more, I will make a grid of plots that are seperated by Churn and contract type.

# %%
sns.displot(data=df, x='tenure', col='Contract', row='Churn');

# %% [markdown]
# ### Showing a scatterplot of total charges vs monthly charges with the hue set as Churn.

# %%
plt.figure(figsize=(14,6))
sns.scatterplot(df, x='MonthlyCharges', y='TotalCharges', hue='Churn', alpha=0.5);

# %% [markdown]
# ### Now I am going to treat each month as its own cohert, from there I can work out the Churn rate/percentage per month.

# %%
yes_churn_perc = []

for month in range(1, 73):
    
    perc = 100 * len(df[(df['tenure'] == month) & (df['Churn'] == 'Yes')]) / len(df[(df['tenure'] == month)])
    yes_churn_perc.append(perc)

# %%
percentage_df = pd.DataFrame(yes_churn_perc, index=range(1, 73), columns=['% of Customer Churn'])

# %%
percentage_df = percentage_df.reset_index().rename(columns={'index': 'Month On Contract'})

# %%
plt.figure(figsize=(14, 6))
sns.lineplot(data=percentage_df, x='Month On Contract', y='% of Customer Churn');

# %% [markdown]
# ### I'd like to make broader cohort groups, for example '0 - 12 Months' etc for tunure.

# %%
bins = [0, 12,  24, 48, df['tenure'].max()]

labels = ['0-12 Months', '12-24 Months', '24-48 Months', 'Over 48 Months']

df['Tenure Cohort'] = pd.cut(df['tenure'], bins=bins, labels=labels, include_lowest=True)

# %%
# Testing with a sample.
df[['tenure', 'Tenure Cohort']].sample(10)
# Out:
#       tenure   Tenure Cohort
# 1218      64  Over 48 Months
# 348       23    12-24 Months
# 4408      17    12-24 Months
# 3999      72  Over 48 Months
# 150        8     0-12 Months
# 5864      18    12-24 Months
# 6041      61  Over 48 Months
# 3750       1     0-12 Months
# 4976      42    24-48 Months
# 6359       2     0-12 Months

# %% [markdown]
# ### Now I will create a scatterplot of the monthly charges against the total charges with the hue set as the new column Tenure Cohort.

# %%
plt.figure(figsize=(14,6))
sns.scatterplot(data=df, x='MonthlyCharges', y='TotalCharges', hue='Tenure Cohort');

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df, hue='Churn', x='Tenure Cohort');

# %% [markdown]
# ### Let's seperate this out by contract type.

# %%
plt.figure(figsize=(12,8))
sns.catplot(data=df, kind='count', x='Tenure Cohort', hue='Churn', col='Contract');

# %% [markdown]
# ## Predictive modelling.

# %% [markdown]
# ### I'll start with a single decision tree and also I will need to sort the data so that is it ready to be used for machine learning.

# %%
X = df.drop(['customerID', 'Tenure Cohort', 'Churn'], axis=1)

# %%
y = df['Churn']

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
dt = DecisionTreeClassifier()

# %%
param_grid = {
    'max_depth': [None, 6, 10, 20, 30, 40],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

grid_search_dt = GridSearchCV(dt, param_grid=param_grid)

# %%
grid_search_dt.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 6, 10, 20, 30, 40],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]})

# %% [markdown]
# ### Now I'll predict off this model and check the metrics.

# %%
dt_preds = grid_search_dt.predict(X_test)

# %%
from sklearn.metrics import ConfusionMatrixDisplay, classification_report

# %%
print(classification_report(y_test, dt_preds))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.85      0.91      0.88       557
#          Yes       0.54      0.38      0.45       147
#
#     accuracy                           0.80       704
#    macro avg       0.69      0.65      0.66       704
# weighted avg       0.78      0.80      0.79       704

# %%
ConfusionMatrixDisplay.from_predictions(y_test, dt_preds);

# %% [markdown]
# ### The best parameters and feature importance.

# %%
grid_search_dt.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 6,
#  'min_samples_leaf': 2,
#  'min_samples_split': 10}

# %%
plt.figure(figsize=(14,8))
plt.title('Importance of Each Column')

feature_importances = grid_search_dt.best_estimator_.feature_importances_

feature_df = pd.DataFrame(feature_importances, index=X_train.columns, columns=['importance']).sort_values('importance')

sns.barplot(data=feature_df, x='importance', y=feature_df.index);

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### I will do the same again but with a random forest, without using a gridsearch.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rf_preds = rf.predict(X_test)

# %%
print(classification_report(y_test, rf_preds))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.86      0.88      0.87       557
#          Yes       0.49      0.44      0.46       147
#
#     accuracy                           0.79       704
#    macro avg       0.67      0.66      0.67       704
# weighted avg       0.78      0.79      0.78       704

# %%
ConfusionMatrixDisplay.from_predictions(y_test, rf_preds);

# %% [markdown]
# ## AdaBoosted Tree

# %% [markdown]
# ### Same again but now i will use AdaBoost and gridsearch.

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.5, 1]
}

# %%
ada_model = AdaBoostClassifier()

# %%
ada_grid = GridSearchCV(ada_model, param_grid=param_grid)

# %%
ada_grid.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=AdaBoostClassifier(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.5, 1],
#                          'n_estimators': [50, 100, 200]})

# %%
ada_preds = ada_grid.predict(X_test)

# %%
print(classification_report(y_test, ada_preds))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.88      0.90      0.89       557
#          Yes       0.60      0.54      0.57       147
#
#     accuracy                           0.83       704
#    macro avg       0.74      0.72      0.73       704
# weighted avg       0.82      0.83      0.83       704

# %%
ConfusionMatrixDisplay.from_predictions(y_test, ada_preds);

# %% [markdown]
# ### From these results, our AdaBoost model performed slightly better than the others, but the amount of 'yes' misclassifications is still not great, further analysis would be needed.
#
# ### This concludes my project and the main goal here was to practise with Tree-Based Methods.
